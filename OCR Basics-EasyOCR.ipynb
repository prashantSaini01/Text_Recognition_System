# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
! pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (1.6.2)
# Requirement already satisfied: scikit-image in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.23.5)
# Requirement already satisfied: ninja in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: Pillow in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (9.3.0)
# Requirement already satisfied: PyYAML in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (0.14.0)
# Requirement already satisfied: Shapely in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.8.5.post1)
# Requirement already satisfied: python-bidi in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.9.3)
# Requirement already satisfied: torch in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: pyclipper in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from torchvision>=0.5->easyocr) (4.4.0)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: six in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (2022.10.10)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (2.22.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (2.8.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.13)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
IMAGE_PATH = '6.jpg'

# %%
IMAGE_PATH
# Out:
# '6.jpg'

# %%
IMAGE_PATH = '6.jpg'
reader = easyocr.Reader(['en'],gpu = False)
result = reader.readtext('surf.jpg',detail=1,paragraph = False)
text = result[0]
text[1]
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 'SURF'

# %%
result = reader.readtext('surf.jpg',detail=1,paragraph = False)
text = result[0]
text[1]
# Out:
# 'SURF'

# %%
text = result[0]
text[1]
# Out:
# 'SURF'

# %%
IMAGE_PATH = 'surf.jpg'
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# Mansi
# chau han

# %%
IMAGE_PATH = '9.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# DATA
# ANALYSIS @.421
# G MAIL |

# %%
from matplotlib import pyplot as plt

IMAGE_PATH = '8.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# DATA
# 'ANALYSIS

# %%
IMAGE_PATH = '10.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Mansi
# chau han

# %%
IMAGE_PATH = '12.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# TEXT

# %% [markdown]
# ### On Vedio

# %%
! pip install Werkzeug
# Out:
# Requirement already satisfied: Werkzeug in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from Werkzeug) (2.1.1)

# %%
import cv2

# %%
camera = cv2.VideoCapture(0)
while True:
    _,Image= camera.read()
    
    cv2.imshow('Text Detection',Image)
    if cv2.waitKey(1)& 0xFF==ord('s'):
        break
camera.relese()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8128/740345405.py in <module>
#       3     _,Image= camera.read()
#       4
# ----> 5     cvShowImage('Text Detection',Image)
#       6     if cv2.waitKey(1)& 0xFF==ord('s'):
#       7         break
#
# NameError: name 'cvShowImage' is not defined

# %%
! pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Handwritten Digit Recognition

# %%
IMAGE_PATH = '4.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# NEVER
# GIVE UP

# %%
IMAGE_PATH = '8.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# DATA
# 'ANALYSIS

# %%
IMAGE_PATH = '9.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# DATA
# ANALYSIS @.421
# G MAIL |

# %%
IMAGE_PATH = '10.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Mansi
# chau han

# %%
IMAGE_PATH = '12.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    print(text)
    
plt.imshow(img)
plt.show()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# TEXT
